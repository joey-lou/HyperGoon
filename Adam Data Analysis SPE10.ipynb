# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn


plt.rcParams['figure.figsize'] = [9, 5]



X_PATH = '/Users/jiujiu/Desktop/496_New_Data'

sim_num = 1


rock_data = np.loadtxt(X_PATH + '/rock/rock' + str(sim_num) + '.txt')
print(rock_data.shape)
#rock_data = np.loadtxt(X_PATH + '/rock' + str(sim_num) + '.txt', delimiter = ',')
rock_data = np.reshape(rock_data,(10,13200),order ='F')
print(rock_data.shape)
#poro_data = rock_data[0,:]
poro_data = np.reshape(rock_data[0,:],(60,220),order ='F')
print(poro_data.shape)
#perm_data = rock_data[(1,2,3),:]
perm_data = np.reshape(rock_data[(1,2,3),:],(3,60,220),order ='F')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-fdd2018c64ec> in <module>
#      15
#      16
# ---> 17 rock_data = np.loadtxt(X_PATH + '/rock/rock' + str(sim_num) + '.txt')
#      18 print(rock_data.shape)
#      19 #rock_data = np.loadtxt(X_PATH + '/rock' + str(sim_num) + '.txt', delimiter = ',')
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#    1099         # converting the data
#    1100         X = None
# -> 1101         for x in read_data(_loadtxt_chunksize):
#    1102             if X is None:
#    1103                 X = np.array(x, dtype)
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1026
#    1027             # Convert each value according to its column and store
# ...

# %% [markdown]
# Porosity

# %%
plt.imshow(poro_data)
plt.colorbar()

plt.title('Porosity')

#plt.savefig('porosity.jpg', dpi=100)
# Out:
# Text(0.5,1,'Porosity')

# %% [markdown]
# Permeabilities

# %%
plt.imshow(perm_data[0,:,:])
plt.colorbar()

plt.title('Water Permeability (mD)')
# Out:
# Text(0.5,1,'Water Permeability (mD)')

# %%
plt.imshow(perm_data[1,:,:])
plt.colorbar()

plt.title('Oil Permeability (mD)')
# Out:
# Text(0.5,1,'Oil Permeability (mD)')

# %%
plt.imshow(perm_data[2,:,:])
plt.colorbar()

plt.title('Gas Permeability (mD)')
# Out:
# Text(0.5,1,'Gas Permeability (mD)')
